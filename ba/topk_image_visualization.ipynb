# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as image

max_img_01 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1049.png")
max_img_02 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_277.png")
max_img_03 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1790.png")
max_img_04 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1535.png")
max_img_05 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1315.png")
max_img_06 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_2434.png")
max_img_07 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1312.png")
max_img_08 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_2441.png")
max_img_09 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_875.png")
max_img_10 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_368.png")
max_img_11 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1611.png")
max_img_12 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1394.png")
max_img_13 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1087.png")
max_img_14 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_2399.png")
max_img_15 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1121.png")
max_img_16 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_988.png")

min_img_01 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1509.png")
min_img_02 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1171.png")
min_img_03 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_2315.png")
min_img_04 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1338.png")
min_img_05 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_136.png")
min_img_06 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1912.png")
min_img_07 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_2410.png")
min_img_08 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1450.png")
min_img_09 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_494.png")
min_img_10 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_1524.png")
min_img_11 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_44.png")
min_img_12 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_2620.png")
min_img_13 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_2595.png")
min_img_14 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_987.png")
min_img_15 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_2513.png")
min_img_16 = image.imread("/home/g037552/Bachelorarbeit_Data/Blender Results/results_top-view_w-o_breasts-param/results_blender/frame_100_id_129.png")

# %%
# Figure: 16x16 silhouettes for max error 

for i in range(1,17):
    plt.subplot(4,4,i)
    img_name = "max_img_" + str(i//10) + str(i%10)
    img = globals()[img_name]
    plt.imshow(img,cmap='gray')

    plt.gca().annotate(
    chr(ord("a")+i-1),
    xy=(0, 0), xycoords='axes fraction',
    xytext=(+0.5, +0.5), textcoords='offset fontsize',
    fontsize='small', verticalalignment='top', fontfamily='serif',
    bbox=dict(facecolor='none', edgecolor='none', pad=0.0))
    plt.axis("off")
    
    plt.savefig('/home/g037552/Bachelorarbeit/output/16x16_Max_error_nopad.png', dpi=600, bbox_inches='tight', pad_inches=0)

# %%
# Figure: 16x16 silhouettes for min error 

for i in range(1,17):
    plt.subplot(4,4,i)
    img_name = "min_img_" + str(i//10) + str(i%10)
    img = globals()[img_name]
    plt.imshow(img,cmap='gray')

    plt.gca().annotate(
    chr(ord("a")+i-1),
    xy=(0, 0), xycoords='axes fraction',
    xytext=(+0.5, +0.5), textcoords='offset fontsize',
    fontsize='small', verticalalignment='top', fontfamily='serif',
    bbox=dict(facecolor='none', edgecolor='none', pad=3.0))
    plt.axis("off")
    
    plt.savefig('/home/g037552/Bachelorarbeit/output/16x16_Min_error.png', dpi=600)

# %%
fig = plt.figure()
plt.subplot(4,4,1)
plt.axis("off")
plt.imshow(max_img_01, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,2)
plt.axis("off")
plt.imshow(max_img_02, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,3)
plt.axis("off")
plt.imshow(max_img_03, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,4)
plt.axis("off")
plt.imshow(max_img_04, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,5)
plt.axis("off")
plt.imshow(max_img_05, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,6)
plt.axis("off")
plt.imshow(max_img_06, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,7)
plt.axis("off")
plt.imshow(max_img_07, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,8)
plt.axis("off")
plt.imshow(max_img_08, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,9)
plt.axis("off")
plt.imshow(max_img_09, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,10)
plt.axis("off")
plt.imshow(max_img_10, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,11)
plt.axis("off")
plt.imshow(max_img_11, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,12)
plt.axis("off")
plt.imshow(max_img_12, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,13)
plt.axis("off")
plt.imshow(max_img_13, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,14)
plt.axis("off")
plt.imshow(max_img_14, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,15)
plt.axis("off")
plt.imshow(max_img_15, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,16)
plt.axis("off")
plt.imshow(max_img_16, cmap=plt.get_cmap('gray'))
fig.tight_layout(pad=0.05)

# %%
plt.subplot(4,4,1)
plt.axis("off")
plt.imshow(min_img_01, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,2)
plt.axis("off")
plt.imshow(min_img_02, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,3)
plt.axis("off")
plt.imshow(min_img_03, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,4)
plt.axis("off")
plt.imshow(min_img_04, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,5)
plt.axis("off")
plt.imshow(min_img_05, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,6)
plt.axis("off")
plt.imshow(min_img_06, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,7)
plt.axis("off")
plt.imshow(min_img_07, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,8)
plt.axis("off")
plt.imshow(min_img_08, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,9)
plt.axis("off")
plt.imshow(min_img_09, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,10)
plt.axis("off")
plt.imshow(min_img_10, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,11)
plt.axis("off")
plt.imshow(min_img_11, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,12)
plt.axis("off")
plt.imshow(min_img_12, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,13)
plt.axis("off")
plt.imshow(min_img_13, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,14)
plt.axis("off")
plt.imshow(min_img_14, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,15)
plt.axis("off")
plt.imshow(min_img_15, cmap=plt.get_cmap('gray'))
plt.subplot(4,4,16)
plt.axis("off")
plt.imshow(min_img_16, cmap=plt.get_cmap('gray'))
fig.tight_layout(pad=0.05)
